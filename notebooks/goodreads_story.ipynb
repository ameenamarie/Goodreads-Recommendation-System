# %% [markdown]
# # Data Story

# %%
# Import libraries
# ----------------

# Pandas
import pandas as pd

# Matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# Numpy
import numpy as np

# %%
# Load data
data = '../data/processed/goodreads.csv'
df = pd.read_csv(data)
print('DataFrame shape: {}'.format(df.shape))
print('Number of unique users:', len(df.user_id.value_counts()))
print('Number of books:', len(df.title.value_counts()))
df.head()
# Out:
# DataFrame shape: (504756, 24)
# Number of unique users: 5423
# Number of books: 1049
#    Unnamed: 0                          authors  average_rating  \
# 0           2  Carlos Ruiz Zafón, Lucia Graves            4.24
# 1           5  Carlos Ruiz Zafón, Lucia Graves            4.24
# 2          16  Carlos Ruiz Zafón, Lucia Graves            4.24
# 3          18  Carlos Ruiz Zafón, Lucia Graves            4.24
# 4          24  Carlos Ruiz Zafón, Lucia Graves            4.24
#
#    avg_rating_by_user  best_book_id  book_id  books_count  goodreads_book_id  \
# 0            3.603774          1232      258          279               1232
# 1            3.463087          1232      258          279               1232
# 2            3.263514          1232      258          279               1232
# 3            3.689441          1232      258          279               1232
# 4            3.506024          1232      258          279               1232
#
# ...

# %%
# Look at the distribution of average ratings per book  
plt.hist(df.average_rating, alpha = 0.6, color='g')
plt.xlabel('average rating')
plt.ylabel('frequency')
plt.title('Distrubtion of Average Rating per Book')
plt.show()

# %%
# Look at the distribution of the average rating per user 
plt.hist(df.avg_rating_by_user, alpha = 0.6, color='g')
plt.xlabel('average rating')
plt.ylabel('frequency')
plt.title('Distrubtion of Average Rating per User')
plt.show()
